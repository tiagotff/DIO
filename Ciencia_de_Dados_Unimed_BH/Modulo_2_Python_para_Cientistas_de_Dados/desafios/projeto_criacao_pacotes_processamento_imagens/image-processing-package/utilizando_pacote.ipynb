# %%
#Importações necessárias
from image_processing.utils import io, plot
from image_processing.processing import combination, transformation
from google.colab import drive

# %%
#Montando ambiente Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Salve as imagens no ambiente Drive montado há pouco
#Passe o caminho das imagens como parametro

image1 = io.read_image("/content/natureza1.jpg")
image2 = io.read_image("/content/natureza2.jpg")

# %%
#Imprimindo as imagens
plot.plot_image(image1)
plot.plot_image(image2)

# %%
#Realizando a combinação das imagens e salvando numa variável
result_image = combination.transfer_histogram(image1, image2)
#Imprimindo resultado da combinação
plot.plot_result(image1, image2, result_image)
